# %% [markdown]
# <a href="https://colab.research.google.com/github/wplusr/wranglers.io/blob/main/aapldiskosbuxwmt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # brands i use everyday 🤠
# i decided to analyze the stocks of companies i interact with almost daily, becuase their brands are basically everywhere and have such a huge reach. my top five are apple, coca-cola, disney, starbucks and walmart.

# %%
import yfinance as yf

# Define the tickers for the companies
tickers = ["AAPL", "KO", "DIS", "SBUX", "WMT"]

# Download the data
data = yf.download(tickers, period="5y")

# Display the first few rows of the data
display(data.head())
# Out:
# /tmp/ipython-input-7-641795697.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, period="5y")
# [*********************100%***********************]  5 of 5 completed
# Price           Close                                                    High  \
# Ticker           AAPL         DIS         KO       SBUX        WMT       AAPL
# Date
# 2020-07-06  90.852013  112.553650  38.865574  67.652481  36.901451  91.321034
# 2020-07-07  90.570099  111.766769  38.848381  66.585327  39.403137  92.011189
# 2020-07-08  92.679497  114.747093  38.728096  66.486664  38.624073  92.711090
# 2020-07-09  93.078056  114.894630  37.731316  65.975517  39.651440  93.627270
# 2020-07-10  93.240860  117.383141  38.796837  66.621185  40.560863  93.299189
#
# Price                                                    ...       Open  \
# Ticker             DIS         KO       SBUX        WMT  ...       AAPL
# ...

# %%
import matplotlib.pyplot as plt

# Select the 'Close' price data
closing_prices = data['Close']

# Plot the closing prices
plt.figure(figsize=(12, 6))
for ticker in closing_prices.columns:
    plt.plot(closing_prices.index, closing_prices[ticker], label=ticker)

plt.title('Stock Closing Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # apple vs disney
# apple has had a serious upward trend because they really leaned into their services, like icloud, that we just can't stop paying for! meanwhile, disney is still adapting and recovering from the pandemic, which hit their parks and movies hard, but they're figuring out how to make their streaming profitable. and it's not like apple has totally figured it out with streaming either, reportedly still losing money on apple tv+.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Illustrative data for Starbucks' total revenue (for a recent fiscal year, e.g., FY2024).
# We sum up the segments to get a total for a simpler comparison.
# *** IMPORTANT: You should update these numbers with actual, recent figures from Starbucks' official financial reports (e.g., their latest 10-K filing) ***
starbucks_total_revenue = 29.76 + 4.51 + 1.9 # Sum of Company-Owned, Licensed, and Other
starbucks_data = {
    'Company': ['Starbucks'],
    'Revenue (Billions USD)': [starbucks_total_revenue]
}
df_starbucks_total = pd.DataFrame(starbucks_data)

# Illustrative data for Coca-Cola's total revenue (for a recent fiscal year, e.g., FY2024).
# *** IMPORTANT: You should update this number with actual, recent total revenue for Coca-Cola ***
coca_cola_data = {
    'Company': ['Coca-Cola'],
    'Revenue (Billions USD)': [47.0] # This is an illustrative total revenue figure
}
df_coca_cola_total = pd.DataFrame(coca_cola_data)

# Combine the DataFrames for both companies into a single DataFrame for direct comparison
df_combined_simple = pd.concat([df_starbucks_total, df_coca_cola_total], ignore_index=True)

# Set a nice style for the plot to make it visually appealing
sns.set_style("whitegrid")
plt.figure(figsize=(8, 6)) # Adjust size for a simpler comparison

# Create a simple bar chart comparing total revenue side-by-side
# 'x' will be the Company, 'y' will be the total Revenue
sns.barplot(x='Company', y='Revenue (Billions USD)', data=df_combined_simple, palette=['#00704A', '#E4002B']) # Starbucks green, Coca-Cola red

# Add a clear title to the chart
plt.title('Starbucks vs. Coca-Cola: Illustrative Total Revenue Comparison', fontsize=16)

# Label the axes for clarity
plt.xlabel('Company', fontsize=12)
plt.ylabel('Total Revenue (Billions USD)', fontsize=12)

# Add the exact revenue values on top of each bar for precise reading
for p in plt.gca().patches:
    height = p.get_height()
    if height > 0:
        plt.text(p.get_x() + p.get_width()/2., height,
                 f'${height:.2f}B',
                 ha='center', va='bottom', fontsize=10)

plt.show()
# Out:
# /tmp/ipython-input-16-382379243.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Company', y='Revenue (Billions USD)', data=df_combined_simple, palette=['#00704A', '#E4002B']) # Starbucks green, Coca-Cola red

# %% [markdown]
# # coca-cola vs starbucks
# when you think about coca-cola and starbucks, it's pretty clear they fit into our lives in totally different ways, even though both are about drinks! coca-cola is that easy grab off the shelf, always there when you need a quick refreshment. starbucks, on the other hand, is more of a cafe experience, where you go for a crafted drink and a specific vibe. sure, they cross paths sometimes, like with bottled Starbucks drinks or fountain Cokes, but for the most part, their personalities and how we interact with them are totally separate.

# %%
import matplotlib.pyplot as plt

# Select the 'Close' price data for Walmart
walmart_closing_prices = data['Close']['WMT']

# Plot the closing prices for Walmart
plt.figure(figsize=(12, 6))
plt.plot(walmart_closing_prices.index, walmart_closing_prices.values, label='WMT', color='blue') # Using Walmart's brand color

plt.title('Walmart Stock Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # walmart
# walmart, the ultimate superstore, has had a wild ride over the last five years, especially in the online world. people thought their massive physical stores might become obsolete one day, but it turns out they're actually perfect for online shopping! this is because walmart can now deliver things super fast through their online and delivery services, leveraging those stores as local hubs.

# %% [markdown]
# # disclaimer
# just a quick but important note: all the insights and observations shared here are purely for informational and entertainment purposes. this is my personal take on the data and brands i interact with, and it's definitely not financial advice or a recommendation to buy or sell any stocks. investing always comes with risks, and you should totally do your own research or chat with a qualified financial advisor before making any investment decisions. thanks for coming along on this data story journey!
